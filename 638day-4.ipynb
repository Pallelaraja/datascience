# %%
import pandas as pd
new=pd.read_csv("C:\\Users\\mohan\\Desktop\\batch 4\\bmi.csv")

# %%
x=new.drop("Index",axis=1)
x
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149      61
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %%
y=new["Index"]
y
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
#       ..
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Index, Length: 500, dtype: int64

# %%
x.shape
# Out:
# (500, 3)

# %%
y.shape
# Out:
# (500,)

# %%
y.shape
# Out:
# (500,)

# %%
#Linear Regression
#Data:

#X(Week)                                              Y(Sales in Thousand)
#--------------------------------------------------------------------------------
#1                                                            1.2
#2                                                            1.8
#3                                                            2.5
#4                                                            3.2
#5                                                            3.8

#Linear regression formula--->y=a0+a1*X

#a1--->(meanof(x*y))-(meanof(x)*meanof(y))/meanof(x^2)-(meanof(x)^2)

# %%
# x         y       x^2         x*y
# 1          1.2       1         1.2
# 2          1.8       4         3.6
# 3          2.5       9         7.5
# 4          3.2       16        12.8
# 5          3.8        25       19
sum:5        12.5       55       44.1
Avg: x=3     y=2.5      11        8.88
  a0=0.69
  a1=0.66
# Out:
#   Cell In[23], line 7
#     sum:5        12.5       55       44.1
#                  ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("C:/Users/mohan/Desktop/batch 4/Linear_regr_Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[['YearsExperience']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 x=df[['YearsExperience']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=69)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 92861.49628543,  68570.75150795, 107809.64691772,  82584.64272573,
#        110612.42516128,  72307.78916603,  64833.71384988,  40542.96907241,
#         56425.37911922,  56425.37911922,  81650.38331121,  45214.266145  ])

# %%
y_test
# Out:
# 21     98274.0
# 14     61112.0
# 24    109432.0
# 19     93941.0
# 25    105583.0
# 15     67939.0
# 13     57082.0
# 2      37732.0
# 8      64446.0
# 7      54446.0
# 18     81364.0
# 3      43526.0
# Name: Salary, dtype: float64

# %%
inputdata=[[17]]
prediction=model.predict(inputdata)
prediction
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([184418.91890822])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x="YearsExperience",y="Salary",data=df,scatter_kws={"color":"white"},line_kws={'color':"skyblue"})
sns.set_style("darkgrid")
ax=plt.gca()
plt.gca().set_facecolor("black")
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df=pd.read_csv("C:/Users/mohan/Desktop/batch 4/LR_Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
dup=df.duplicated().sum()
dup
# Out:
# 127

# %%
df7=df.drop_duplicates()
df7.duplicated().sum()
# Out:
# 0

# %%
print("after droping duplicates ")
df7
# Out:
# after droping duplicates
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df7.shape
# Out:
# (9873, 6)

# %%
response=df7['Performance Index']

# %%
response.dtype
# Out:
# dtype('float64')

# %%
plt.plot(response.index,response)
plt.xlabel('index')
plt.ylabel('Performance Index')
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
sns.jointplot(response,color="red")
plt.xlabel('index')
plt.ylabel('Performance Index')
# Out:
# Text(40.347222222222214, 0.5, 'Performance Index')

# %%
sns.violinplot(response,color="black")
# Out:
# <Axes: >

# %%
min=response.min()
max=response.max()

# %%
(df7["Performance Index"]==min).sum()
# Out:
# 1

# %%
(df7["Performance Index"]==max).sum()
# Out:
# 3

# %%
df7["Hours Studied"].value_counts()
# Out:
# Hours Studied
# 1    1133
# 6    1122
# 7    1118
# 3    1110
# 9    1099
# 2    1077
# 8    1074
# 4    1071
# 5    1069
# Name: count, dtype: int64

# %%
df7["Hours Studied"].unique()
# Out:
# array([7, 4, 8, 5, 3, 6, 2, 1, 9], dtype=int64)

# %%
o
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="Hours Studied",y="Performance Index",data=df7,color="black")
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
y=10000-(df7["Extracurricular Activities"].value_counts())
sns.histplot(x="Extracurricular Activities",y,data=df7,color="black")
# Out:
#   Cell In[78], line 4
#     sns.histplot(x="Extracurricular Activities",y,data=df7,color="black")
#                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.histplot(df7['Extracurricular Activities'])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Count'>

# %%
df7.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df7['Extracurricular Activities'] = df['Extracurricular Activities'].replace({'Yes': 1, 'No': 0})
x=df7[['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
       'Sleep Hours', 'Sample Question Papers Practiced']]
# Out:
# C:\Users\mohan\AppData\Local\Temp\ipykernel_13844\586349689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Extracurricular Activities'] = df['Extracurricular Activities'].replace({'Yes': 1, 'No': 0})

# %%
y=df7["Performance Index"]

# %%
df7['Extracurricular Activities'].apply(lambda x:1 if x=="Yes" else 0)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Extracurricular Activities, Length: 9873, dtype: int64

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=69)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([68.44105451, 70.28100873, 72.16734087, ..., 33.84289061,
#        89.78892287, 62.39819697])

# %%
import numpy as np
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,np.round(y_pred))
a
# Out:
# 0.20430379746835442

# %%
data=[[1,2,3,4,5]]
prediction=model.predict(data)
prediction
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-24.4083208])

# %%
from sklearn.linear_model import Ridge
clf=Ridge()
clf.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([68.4413397 , 70.28123287, 72.16724342, ..., 33.84279568,
#        89.78837209, 62.39806877])
